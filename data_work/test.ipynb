# %%
import pandas as pd 
import json

# %%
with open('../fash-data/letter_A.json', 'r') as f:
    data = json.load(f)

print(data[0])
# Out:
# {'Designer': 'À La Garçonne', 'Shows': [{'Show Name': 'São Paulo Resort 2017', 'Looks': [{'Look_Url': 'https://assets.vogue.com/photos/5811b1e6430bf76f0e335edf/master/w_1024,c_limit/_ALA0013.jpg', 'Garments': {}, 'Look_Number': 1}, {'Look_Url': 'https://assets.vogue.com/photos/5811b1f61e4d8f712cb38ee3/master/w_1024,c_limit/_ALA0021.jpg', 'Garments': {}, 'Look_Number': 2}, {'Look_Url': 'https://assets.vogue.com/photos/5811b1f41c667ee549722fdf/master/w_1024,c_limit/_ALA0027.jpg', 'Garments': {}, 'Look_Number': 3}, {'Look_Url': 'https://assets.vogue.com/photos/5811b243a492d9f07e6c634d/master/w_1024,c_limit/_ALA0037.jpg', 'Garments': {}, 'Look_Number': 4}, {'Look_Url': 'https://assets.vogue.com/photos/5811b1fe0914547b3db4285b/master/w_1024,c_limit/_ALA0046.jpg', 'Garments': {}, 'Look_Number': 5}, {'Look_Url': 'https://assets.vogue.com/photos/5811b21a1e4d8f712cb38ee9/master/w_1024,c_limit/_ALA0049.jpg', 'Garments': {}, 'Look_Number': 6}, {'Look_Url': 'https://assets.vogue.com/photos/5811b
# ...
