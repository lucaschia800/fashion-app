# %%
import json

# %%
import json 

with open('letter_A.json', 'r') as f:
    data = json.load(f)

# %%
print(len(data))
print(data[100])
# Out:
# 1980
# ...

# %%
print(data[2]['Shows'][0])
# Out:
# {'Show Name': 'Tokyo Fall 2015', 'Looks': [{'Look_Url': 'https://assets.vogue.com/photos/55c650b508298d8be214cb8d/master/w_1024,c_limit/a-degree-fahrenheit-001-1366.jpg', 'Garments': {'labels': [9], 'boxes': [[469.7756652832031, 1239.32666015625, 555.2425537109375, 1470.0941162109375]], 'scores': [0.9663115739822388]}, 'Look_Number': 1}, {'Look_Url': 'https://assets.vogue.com/photos/55c650b508298d8be214cb8e/master/w_1024,c_limit/a-degree-fahrenheit-002-1366.jpg', 'Garments': {'labels': [4], 'boxes': [[358.7978515625, 643.8610229492188, 676.1921997070312, 1301.2227783203125]], 'scores': [0.9935814142227173]}, 'Look_Number': 2}, {'Look_Url': 'https://assets.vogue.com/photos/55c650b508298d8be214cb8f/master/w_1024,c_limit/a-degree-fahrenheit-003-1366.jpg', 'Garments': {'labels': [9, 4, 3], 'boxes': [[409.80810546875, 1252.217041015625, 584.1920166015625, 1465.6669921875], [388.6930847167969, 962.6688842773438, 603.7940673828125, 1362.7054443359375], [244.85171508789062, 284.5988464355469
# ...

# %%
print('test')
# Out:
# test
