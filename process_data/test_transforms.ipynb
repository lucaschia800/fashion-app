# %%
import json
from io import BytesIO
from concurrent.futures import ThreadPoolExecutor, as_completed
from typing import List, Dict, Tuple
import copy

import torch
from PIL import Image
import requests
from tqdm import tqdm
from torchvision.models import EfficientNet_V2_M_Weights

from torchvision.models.detection import fasterrcnn_resnet50_fpn_v2, FasterRCNN_ResNet50_FPN_V2_Weights
from torchvision.transforms import functional as F
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor

# %%
transforms = FasterRCNN_ResNet50_FPN_V2_Weights.DEFAULT.transforms()




print(transforms)


print(transforms)
# Out:
# ObjectDetection()
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 9
#       1 transforms = FasterRCNN_ResNet50_FPN_V2_Weights.DEFAULT.transforms()
#       6 print(transforms)
# ----> 9 print(transforms[0])
#
# TypeError: 'ObjectDetection' object is not subscriptable

# %%
type(transforms)
# Out:
# torchvision.transforms._presets.ObjectDetection

# %%
image = Image.open('../fash-data/shanghai-spring-2025/markgong-shanghai-spring-2025-0.png').convert('RGB')

# %%
transformed_image = transforms(image)

# %%
type(transformed_image)
# Out:
# torch.Tensor
